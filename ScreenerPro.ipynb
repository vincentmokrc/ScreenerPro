# %%
import urllib.request
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
listing_directory = "https://www.bursamalaysia.com/trade/trading_resources/listing_directory/"
main_market = "main_market"
ace_market = "ace_market"
leap_market = "leap_market"
lfx_market = "lfx_market"
pn17_and_gn13_companies = "pn17_and_gn13_companies"
change_of_name = "change_of_name"
slash = "/"

# %%
url_is = listing_directory + main_market

# %%
driver = webdriver.Firefox()

# %%
driver.get(url_is)

# %%
select = driver.find_element_by_name('DataTables_Table_0_length')

# %%
select.select_by_value('All')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-797458f7de74> in <module>
# ----> 1 select.select_by_value('All')
#
# AttributeError: 'FirefoxWebElement' object has no attribute 'select_by_value'

# %%
driver.find_element_by_xpath("//select[@name='DataTables_Table_0_length']/option[text()='All']").click()

# %%
tutorial_soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
table = tutorial_soup.find('table', id="DataTables_Table_0")

# %%
table_rows = table.find_all('tr')

# %%
res = []
for tr in table_rows:
    td = tr.find_all('td')
    td2 = tr.find_all('td')[1:2]
    for d in td2: 
        a = d.find_all('a', href=True)
        for b in a:
            code=b['href'].split('stock_code=')[1]
            print(code)
            
    row = [d.text.strip() for d in td]
    print(row)
    
    row.append(code)
    
    if row:
        res.append(row)
# Out:
# []
# 5250
# ['1', '7-ELEVEN MALAYSIA HOLDINGS BERHAD', 'http://www.7eleven.com.my']
# 7214
# ['2', 'A-RANK BERHAD [S]', 'http://www.arank.com.my']
# 7086
# ['3', 'ABLEGROUP BERHAD [S]', 'http://www.ablegroup.com.my/']
# 5198
# ['4', 'ABM FUJIYA BERHAD [S]', 'http://www.abmfujiya.com.my']
# 7131
# ['5', 'ACME HOLDINGS BERHAD [S]', 'https://www.acmeholdings.com.my']
# 7120
# ['6', 'ACOUSTECH BERHAD [S]', 'http://www.acoustech.com.my/']
# 1481
# ['7', 'ADVANCE SYNERGY BERHAD', 'http://www.asb.com.my']
# 5281
# ['8', 'ADVANCECON HOLDINGS BERHAD [S]', 'http://www.advancecon.com.my/']
# 9148
# ['9', 'ADVANCED PACKAGING TECHNOLOGY (M) BHD [S]', 'http://www.advancedpack.com.my']
# 7191
# ['10', 'ADVENTA BERHAD [S]', 'http://www.adventa.com.my']
# 7146
# ['11', 'AE MULTI HOLDINGS BERHAD [S]', 'http://www.amallionpcb.com']
# 6599
# ['12', 'AEON CO. (M) BHD [S]', 'http://www.aeonretail.com.my']
# 5139
# ['13', 'AEON CREDIT SERVICE (M) BERHAD', 'https://www.aeoncredit.com.my/']
# 5185
# ...

# %%
res
# Out:
# [['1', '7-ELEVEN MALAYSIA HOLDINGS BERHAD', 'http://www.7eleven.com.my'],
#  ['2', 'A-RANK BERHAD [S]', 'http://www.arank.com.my'],
#  ['3', 'ABLEGROUP BERHAD [S]', 'http://www.ablegroup.com.my/'],
#  ['4', 'ABM FUJIYA BERHAD [S]', 'http://www.abmfujiya.com.my'],
#  ['5', 'ACME HOLDINGS BERHAD [S]', 'https://www.acmeholdings.com.my'],
#  ['6', 'ACOUSTECH BERHAD [S]', 'http://www.acoustech.com.my/'],
#  ['7', 'ADVANCE SYNERGY BERHAD', 'http://www.asb.com.my'],
#  ['8', 'ADVANCECON HOLDINGS BERHAD [S]', 'http://www.advancecon.com.my/'],
#  ['9',
#   'ADVANCED PACKAGING TECHNOLOGY (M) BHD [S]',
#   'http://www.advancedpack.com.my'],
#  ['10', 'ADVENTA BERHAD [S]', 'http://www.adventa.com.my'],
#  ['11', 'AE MULTI HOLDINGS BERHAD [S]', 'http://www.amallionpcb.com'],
#  ['12', 'AEON CO. (M) BHD [S]', 'http://www.aeonretail.com.my'],
#  ['13', 'AEON CREDIT SERVICE (M) BERHAD', 'https://www.aeoncredit.com.my/'],
#  ['14', 'AFFIN BANK BERHAD', 'http://www.affin.com.my'],
# ...

# %%
df = pd.DataFrame(res, columns=["No","Company Name", "Company Website","Code"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\users\vince\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# c:\users\vince\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 4 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[1:]
# Out:
#     No                               Company Name  \
# 1    1          7-ELEVEN MALAYSIA HOLDINGS BERHAD
# 2    2                          A-RANK BERHAD [S]
# 3    3                       ABLEGROUP BERHAD [S]
# 4    4                      ABM FUJIYA BERHAD [S]
# 5    5                   ACME HOLDINGS BERHAD [S]
# 6    6                       ACOUSTECH BERHAD [S]
# 7    7                     ADVANCE SYNERGY BERHAD
# 8    8             ADVANCECON HOLDINGS BERHAD [S]
# 9    9  ADVANCED PACKAGING TECHNOLOGY (M) BHD [S]
# 10  10                         ADVENTA BERHAD [S]
# 11  11               AE MULTI HOLDINGS BERHAD [S]
# 12  12                       AEON CO. (M) BHD [S]
# 13  13             AEON CREDIT SERVICE (M) BERHAD
# 14  14                          AFFIN BANK BERHAD
# 15  15          PRINSIPTEK CORPORATION BERHAD [S]
# 16  16                    AHB HOLDINGS BERHAD [S]
# 17  17            AHMAD ZAKI RESOURCES BERHAD [S]
# 18  18                   AIRASIA GROUP BERHAD [S]
# ...
